# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
input_file =  'http://bit.ly/2U18s5V' 
ship = pd.read_csv(input_file); ship.head(4)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000

# %%
ship.shape
# Out:
# (887, 8)

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
# Survived                   887 non-null int64
# Pclass                     887 non-null int64
# Name                       887 non-null object
# Sex                        887 non-null object
# Age                        887 non-null float64
# Siblings/Spouses Aboard    887 non-null int64
# Parents/Children Aboard    887 non-null int64
# Fare                       887 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
ship = ship.rename(columns = {'Siblings/Spouses Aboard': 'SibSp', 'Parents/Children Aboard' : 'Parch' }); ship.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
ship.Survived = ship['Survived'].astype('category')
ship['Pclass'] = ship.Pclass.astype('category')

# %%
sns.set()
sns.distplot (ship.Fare, color='g', bins=20) ;

# %%
plt.figure(figsize=[14,3])
sns.boxplot(ship.Fare);

# %%
ship [ship.Fare > 500]
# Out:
#     Survived Pclass                               Name     Sex   Age  SibSp  \
# 257        1      1                    Miss. Anna Ward  female  35.0      0
# 676        1      1  Mr. Thomas Drake Martinez Cardeza    male  36.0      0
# 733        1      1              Mr. Gustave J Lesurer    male  35.0      0
#
#      Parch      Fare
# 257      0  512.3292
# 676      1  512.3292
# 733      0  512.3292

# %%
sns.catplot(x='Survived', y = 'Fare', data = ship, hue='Pclass');

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'Fare']
df = ship [cols].copy()

# %%
sns.pairplot(df, hue='Survived');

# %%
ship[ship.Age > 70]
# Out:
#     Survived Pclass                                 Name   Sex   Age  SibSp  \
# 95         0      1             Mr. George B Goldschmidt  male  71.0      0
# 115        0      3                  Mr. Patrick Connors  male  70.5      0
# 490        0      1               Mr. Ramon Artagaveytia  male  71.0      0
# 627        1      1  Mr. Algernon Henry Wilson Barkworth  male  80.0      0
# 847        0      3                   Mr. Johan Svensson  male  74.0      0
#
#      Parch     Fare
# 95       0  34.6542
# 115      0   7.7500
# 490      0  49.5042
# 627      0  30.0000
# 847      0   7.7750
